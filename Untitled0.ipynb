# %% [markdown]
# <a href="https://colab.research.google.com/github/Cjsvntf/GC/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colabcode

# %%
from colabcode import ColabCode

# %%
ColabCode(port=10000)
